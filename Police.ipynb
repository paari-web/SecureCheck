# %%
import mysql.connector
mydb = mysql.connector.connect(
 host="localhost",
 user="root",
 password="",
)
print(mydb)
mycursor = mydb.cursor(buffered=True)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x0000020B95A44FE0>

# %%
import pandas as pd

file_path = r'C:\Users\sivar\Downloads\traffic_stops - traffic_stops_with_vehicle_number.csv'
df = pd.read_csv(file_path)
# Out:
# C:\Users\sivar\AppData\Local\Temp\ipykernel_7612\2670477484.py:4: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# 0              19       Asian     Drunk Driving  Speeding              True
# 1              58       Other             Other     Other             False
# 2              76       Black  Signal Violation  Speeding             False
# 3              76       Black          Speeding       DUI              True
# 4              75       Other          Speeding     Other             False
# ...           ...         ...               ...       ...               ...
# 65533          48       Black             Other     Other             False
# 65534          35    Hispanic          Seatbelt     Other              True
# 65535          41       Asian          Seatbelt       DUI              True
# 65536          63       Black          Seatbelt     Other             False
# 65537          32       Other          Seatbelt  Speeding              True
#
#           search_type stop_outcome  is_arrested stop_duration  \
# 0      Vehicle Search       Ticket         True     16-30 Min
# 1      Vehicle Search       Arrest         True     16-30 Min
# 2               Frisk       Ticket         True     16-30 Min
# 3               Frisk      Warning        False      0-15 Min
# 4      Vehicle Search       Arrest         True     16-30 Min
# ...               ...          ...          ...           ...
# 65533  Vehicle Search       Arrest         True     16-30 Min
# 65534  Vehicle Search       Ticket        False     16-30 Min
# 65535           Frisk       Ticket         True       30+ Min
# 65536             NaN      Warning         True      0-15 Min
# 65537             NaN       Ticket         True     16-30 Min
#
#        drugs_related_stop vehicle_number
# 0                    True     UP76DY3473
# 1                    True     RJ83PZ4441
# 2                    True     RJ32OM7264
# 3                    True     RJ76TI3807
# 4                   False     WB63BB8305
# ...                   ...            ...
# 65533               False     DL56GW6568
# 65534                True     TN73EO7098
# 65535                True     GJ33MX8328
# 65536                True     KA24UZ8488
# 65537               False     UP89PT2924
#
# [65538 rows x 16 columns]

# %%
print(df.columns[10])
# Out:
# search_type

# %%
print(df.dtypes)
# Out:
# stop_date             object
# stop_time             object
# country_name          object
# driver_gender         object
# driver_age_raw         int64
# driver_age             int64
# driver_race           object
# violation_raw         object
# violation             object
# search_conducted        bool
# search_type           object
# stop_outcome          object
# is_arrested             bool
# stop_duration         object
# drugs_related_stop      bool
# vehicle_number        object
# dtype: object

# %%
print(df['search_type'].unique())
# Out:
# ['Vehicle Search' 'Frisk' nan]

# %%
df['search_type'] = df['search_type'].fillna('No Search')
print(df['search_type'].unique())
# Out:
# ['Vehicle Search' 'Frisk' 'No Search']

# %%
print(df['search_type'].value_counts(dropna=False))
# Out:
# search_type
# Frisk             21971
# Vehicle Search    21847
# No Search         21720
# Name: count, dtype: int64

# %%
print(df[['search_type']].head(10))  # First 10 rows
# Out:
#       search_type
# 0  Vehicle Search
# 1  Vehicle Search
# 2           Frisk
# 3           Frisk
# 4  Vehicle Search
# 5  Vehicle Search
# 6  Vehicle Search
# 7       No Search
# 8           Frisk
# 9       No Search

# %%
display(df)
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# 0              19       Asian     Drunk Driving  Speeding              True
# 1              58       Other             Other     Other             False
# 2              76       Black  Signal Violation  Speeding             False
# 3              76       Black          Speeding       DUI              True
# 4              75       Other          Speeding     Other             False
# ...           ...         ...               ...       ...               ...
# 65533          48       Black             Other     Other             False
# 65534          35    Hispanic          Seatbelt     Other              True
# 65535          41       Asian          Seatbelt       DUI              True
# 65536          63       Black          Seatbelt     Other             False
# 65537          32       Other          Seatbelt  Speeding              True
#
#           search_type stop_outcome  is_arrested stop_duration  \
# 0      Vehicle Search       Ticket         True     16-30 Min
# 1      Vehicle Search       Arrest         True     16-30 Min
# 2               Frisk       Ticket         True     16-30 Min
# 3               Frisk      Warning        False      0-15 Min
# 4      Vehicle Search       Arrest         True     16-30 Min
# ...               ...          ...          ...           ...
# 65533  Vehicle Search       Arrest         True     16-30 Min
# 65534  Vehicle Search       Ticket        False     16-30 Min
# 65535           Frisk       Ticket         True       30+ Min
# 65536       No Search      Warning         True      0-15 Min
# 65537       No Search       Ticket         True     16-30 Min
#
#        drugs_related_stop vehicle_number
# 0                    True     UP76DY3473
# 1                    True     RJ83PZ4441
# 2                    True     RJ32OM7264
# 3                    True     RJ76TI3807
# 4                   False     WB63BB8305
# ...                   ...            ...
# 65533               False     DL56GW6568
# 65534                True     TN73EO7098
# 65535                True     GJ33MX8328
# 65536                True     KA24UZ8488
# 65537               False     UP89PT2924
#
# [65538 rows x 16 columns]

# %%
df.to_csv(r'C:\Users\sivar\Downloads\traffic_stops_cleaned.csv', index=False)

# %%
import pandas as pd

# Load your data
df = pd.read_csv(r'C:\Users\sivar\Downloads\traffic_stops_cleaned.csv')

# Drop the unnecessary columns
df = df.drop(columns=['driver_age_raw', 'violation_raw'])

# Save cleaned dataset
df.to_csv(r'C:\Users\sivar\Downloads\traffic_stops_final.csv', index=False)

print('Removed redundant columns and saved as traffic_stops_final.csv')
# Out:
# Removed redundant columns and saved as traffic_stops_final.csv

# %%
import pandas as pd

file_path = r'C:\Users\sivar\Downloads\traffic_stops_final.csv'
df = pd.read_csv(file_path)

# %%
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age  \
# 0      2020-01-01   0:00:00       Canada             M          19
# 1      2020-01-01   0:01:00        India             M          58
# 2      2020-01-01   0:02:00          USA             M          76
# 3      2020-01-01   0:03:00       Canada             M          76
# 4      2020-01-01   0:04:00       Canada             M          75
# ...           ...       ...          ...           ...         ...
# 65533  2020-02-15  12:13:00        India             F          48
# 65534  2020-02-15  12:14:00       Canada             F          35
# 65535  2020-02-15  12:15:00          USA             M          41
# 65536  2020-02-15  12:16:00       Canada             F          63
# 65537  2020-02-15  12:17:00          USA             F          32
#
#       driver_race violation  search_conducted     search_type stop_outcome  \
# 0           Asian  Speeding              True  Vehicle Search       Ticket
# 1           Other     Other             False  Vehicle Search       Arrest
# 2           Black  Speeding             False           Frisk       Ticket
# 3           Black       DUI              True           Frisk      Warning
# 4           Other     Other             False  Vehicle Search       Arrest
# ...           ...       ...               ...             ...          ...
# 65533       Black     Other             False  Vehicle Search       Arrest
# 65534    Hispanic     Other              True  Vehicle Search       Ticket
# 65535       Asian       DUI              True           Frisk       Ticket
# 65536       Black     Other             False       No Search      Warning
# 65537       Other  Speeding              True       No Search       Ticket
#
#        is_arrested stop_duration  drugs_related_stop vehicle_number
# 0             True     16-30 Min                True     UP76DY3473
# 1             True     16-30 Min                True     RJ83PZ4441
# 2             True     16-30 Min                True     RJ32OM7264
# 3            False      0-15 Min                True     RJ76TI3807
# 4             True     16-30 Min               False     WB63BB8305
# ...            ...           ...                 ...            ...
# 65533         True     16-30 Min               False     DL56GW6568
# 65534        False     16-30 Min                True     TN73EO7098
# 65535         True       30+ Min                True     GJ33MX8328
# 65536         True      0-15 Min                True     KA24UZ8488
# 65537         True     16-30 Min               False     UP89PT2924
#
# [65538 rows x 14 columns]

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df['stop_date'] = pd.to_datetime(df['stop_date'], errors='coerce')
df['stop_time'] = pd.to_datetime(df['stop_time'], format='%H:%M', errors='coerce').dt.time

# %%
df
# Out:
#        stop_date stop_time country_name driver_gender  driver_age driver_race  \
# 0     2020-01-01       NaT       Canada             M          19       Asian
# 1     2020-01-01       NaT        India             M          58       Other
# 2     2020-01-01       NaT          USA             M          76       Black
# 3     2020-01-01       NaT       Canada             M          76       Black
# 4     2020-01-01       NaT       Canada             M          75       Other
# ...          ...       ...          ...           ...         ...         ...
# 65533 2020-02-15       NaT        India             F          48       Black
# 65534 2020-02-15       NaT       Canada             F          35    Hispanic
# 65535 2020-02-15       NaT          USA             M          41       Asian
# 65536 2020-02-15       NaT       Canada             F          63       Black
# 65537 2020-02-15       NaT          USA             F          32       Other
#
#       violation  search_conducted     search_type stop_outcome  is_arrested  \
# 0      Speeding              True  Vehicle Search       Ticket         True
# 1         Other             False  Vehicle Search       Arrest         True
# 2      Speeding             False           Frisk       Ticket         True
# 3           DUI              True           Frisk      Warning        False
# 4         Other             False  Vehicle Search       Arrest         True
# ...         ...               ...             ...          ...          ...
# 65533     Other             False  Vehicle Search       Arrest         True
# 65534     Other              True  Vehicle Search       Ticket        False
# 65535       DUI              True           Frisk       Ticket         True
# 65536     Other             False       No Search      Warning         True
# 65537  Speeding              True       No Search       Ticket         True
#
#       stop_duration  drugs_related_stop vehicle_number
# 0         16-30 Min                True     UP76DY3473
# 1         16-30 Min                True     RJ83PZ4441
# 2         16-30 Min                True     RJ32OM7264
# 3          0-15 Min                True     RJ76TI3807
# 4         16-30 Min               False     WB63BB8305
# ...             ...                 ...            ...
# 65533     16-30 Min               False     DL56GW6568
# 65534     16-30 Min                True     TN73EO7098
# 65535       30+ Min                True     GJ33MX8328
# 65536      0-15 Min                True     KA24UZ8488
# 65537     16-30 Min               False     UP89PT2924
#
# [65538 rows x 14 columns]

# %%
print(df['stop_date'].isna().sum())
print(df['stop_time'].isna().sum())
# Out:
# 0
# 0

# %%
df['stop_time'] = pd.to_datetime(
    df['stop_time'], errors='coerce'
).dt.time

# %%
df
# Out:
#        stop_date stop_time country_name driver_gender  driver_age driver_race  \
# 0     2020-01-01       NaT       Canada             M          19       Asian
# 1     2020-01-01       NaT        India             M          58       Other
# 2     2020-01-01       NaT          USA             M          76       Black
# 3     2020-01-01       NaT       Canada             M          76       Black
# 4     2020-01-01       NaT       Canada             M          75       Other
# ...          ...       ...          ...           ...         ...         ...
# 65533 2020-02-15       NaT        India             F          48       Black
# 65534 2020-02-15       NaT       Canada             F          35    Hispanic
# 65535 2020-02-15       NaT          USA             M          41       Asian
# 65536 2020-02-15       NaT       Canada             F          63       Black
# 65537 2020-02-15       NaT          USA             F          32       Other
#
#       violation  search_conducted     search_type stop_outcome  is_arrested  \
# 0      Speeding              True  Vehicle Search       Ticket         True
# 1         Other             False  Vehicle Search       Arrest         True
# 2      Speeding             False           Frisk       Ticket         True
# 3           DUI              True           Frisk      Warning        False
# 4         Other             False  Vehicle Search       Arrest         True
# ...         ...               ...             ...          ...          ...
# 65533     Other             False  Vehicle Search       Arrest         True
# 65534     Other              True  Vehicle Search       Ticket        False
# 65535       DUI              True           Frisk       Ticket         True
# 65536     Other             False       No Search      Warning         True
# 65537  Speeding              True       No Search       Ticket         True
#
#       stop_duration  drugs_related_stop vehicle_number
# 0         16-30 Min                True     UP76DY3473
# 1         16-30 Min                True     RJ83PZ4441
# 2         16-30 Min                True     RJ32OM7264
# 3          0-15 Min                True     RJ76TI3807
# 4         16-30 Min               False     WB63BB8305
# ...             ...                 ...            ...
# 65533     16-30 Min               False     DL56GW6568
# 65534     16-30 Min                True     TN73EO7098
# 65535       30+ Min                True     GJ33MX8328
# 65536      0-15 Min                True     KA24UZ8488
# 65537     16-30 Min               False     UP89PT2924
#
# [65538 rows x 14 columns]

# %%
original_times = pd.read_csv(file_path, usecols=['stop_time'])
df['stop_time'] = original_times['stop_time']

# %%
df
# Out:
#        stop_date stop_time country_name driver_gender  driver_age driver_race  \
# 0     2020-01-01   0:00:00       Canada             M          19       Asian
# 1     2020-01-01   0:01:00        India             M          58       Other
# 2     2020-01-01   0:02:00          USA             M          76       Black
# 3     2020-01-01   0:03:00       Canada             M          76       Black
# 4     2020-01-01   0:04:00       Canada             M          75       Other
# ...          ...       ...          ...           ...         ...         ...
# 65533 2020-02-15  12:13:00        India             F          48       Black
# 65534 2020-02-15  12:14:00       Canada             F          35    Hispanic
# 65535 2020-02-15  12:15:00          USA             M          41       Asian
# 65536 2020-02-15  12:16:00       Canada             F          63       Black
# 65537 2020-02-15  12:17:00          USA             F          32       Other
#
#       violation  search_conducted     search_type stop_outcome  is_arrested  \
# 0      Speeding              True  Vehicle Search       Ticket         True
# 1         Other             False  Vehicle Search       Arrest         True
# 2      Speeding             False           Frisk       Ticket         True
# 3           DUI              True           Frisk      Warning        False
# 4         Other             False  Vehicle Search       Arrest         True
# ...         ...               ...             ...          ...          ...
# 65533     Other             False  Vehicle Search       Arrest         True
# 65534     Other              True  Vehicle Search       Ticket        False
# 65535       DUI              True           Frisk       Ticket         True
# 65536     Other             False       No Search      Warning         True
# 65537  Speeding              True       No Search       Ticket         True
#
#       stop_duration  drugs_related_stop vehicle_number
# 0         16-30 Min                True     UP76DY3473
# 1         16-30 Min                True     RJ83PZ4441
# 2         16-30 Min                True     RJ32OM7264
# 3          0-15 Min                True     RJ76TI3807
# 4         16-30 Min               False     WB63BB8305
# ...             ...                 ...            ...
# 65533     16-30 Min               False     DL56GW6568
# 65534     16-30 Min                True     TN73EO7098
# 65535       30+ Min                True     GJ33MX8328
# 65536      0-15 Min                True     KA24UZ8488
# 65537     16-30 Min               False     UP89PT2924
#
# [65538 rows x 14 columns]

# %%
print(df['stop_time'].head(10))
# Out:
# 0    00:00:00
# 1    00:01:00
# 2    00:02:00
# 3    00:03:00
# 4    00:04:00
# 5    00:05:00
# 6    00:06:00
# 7    00:07:00
# 8    00:08:00
# 9    00:09:00
# Name: stop_time, dtype: object

# %%
df['stop_time'] = pd.to_datetime(
    df['stop_time'],
    errors='coerce'
).dt.time
# Out:
# C:\Users\sivar\AppData\Local\Temp\ipykernel_7612\673948437.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['stop_time'] = pd.to_datetime(

# %%
df['stop_time'] = pd.to_datetime(
    df['stop_time'],
    format='%H:%M:%S',
    errors='coerce'
).dt.time

# %%
print(df['stop_time'].head(10))
# Out:
# 0    00:00:00
# 1    00:01:00
# 2    00:02:00
# 3    00:03:00
# 4    00:04:00
# 5    00:05:00
# 6    00:06:00
# 7    00:07:00
# 8    00:08:00
# 9    00:09:00
# Name: stop_time, dtype: object

# %%
print(type(df['stop_time'].iloc[0]))
# Out:
# <class 'datetime.time'>

# %%
df.to_csv(r'C:\Users\sivar\Downloads\traffic_stops_final2.csv', index=False)

# %%
df = df[(df['driver_age'] >= 16) & (df['driver_age'] <= 100)]

# %%
df[df['driver_age'] >70]
# Out:
#        stop_date stop_time country_name driver_gender  driver_age driver_race  \
# 2     2020-01-01  00:02:00          USA             M          76       Black
# 3     2020-01-01  00:03:00       Canada             M          76       Black
# 4     2020-01-01  00:04:00       Canada             M          75       Other
# 5     2020-01-01  00:05:00       Canada             F          73       Other
# 10    2020-01-01  00:10:00        India             F          76       Black
# ...          ...       ...          ...           ...         ...         ...
# 65513 2020-02-15  11:53:00        India             F          79       Black
# 65521 2020-02-15  12:01:00        India             M          78       Asian
# 65522 2020-02-15  12:02:00          USA             M          80    Hispanic
# 65529 2020-02-15  12:09:00        India             F          78       Black
# 65530 2020-02-15  12:10:00        India             M          72       White
#
#       violation  search_conducted     search_type stop_outcome  is_arrested  \
# 2      Speeding             False           Frisk       Ticket         True
# 3           DUI              True           Frisk      Warning        False
# 4         Other             False  Vehicle Search       Arrest         True
# 5         Other              True  Vehicle Search       Ticket        False
# 10       Signal             False       No Search       Ticket        False
# ...         ...               ...             ...          ...          ...
# 65513       DUI              True       No Search       Ticket        False
# 65521  Seatbelt             False  Vehicle Search       Ticket        False
# 65522  Seatbelt              True  Vehicle Search       Arrest         True
# 65529  Seatbelt              True       No Search      Warning        False
# 65530  Seatbelt              True       No Search       Ticket         True
#
#       stop_duration  drugs_related_stop vehicle_number
# 2         16-30 Min                True     RJ32OM7264
# 3          0-15 Min                True     RJ76TI3807
# 4         16-30 Min               False     WB63BB8305
# 5         16-30 Min               False     MH89ZF7676
# 10          30+ Min                True     UP67CQ9426
# ...             ...                 ...            ...
# 65513       30+ Min                True     UP83UH8771
# 65521       30+ Min                True     MH42PF3736
# 65522       30+ Min               False     RJ87IU6720
# 65529      0-15 Min               False     DL13IZ8119
# 65530       30+ Min               False     KA65MU9353
#
# [10426 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# stop_date             0
# stop_time             0
# country_name          0
# driver_gender         0
# driver_age            0
# driver_race           0
# violation             0
# search_conducted      0
# search_type           0
# stop_outcome          0
# is_arrested           0
# stop_duration         0
# drugs_related_stop    0
# vehicle_number        0
# dtype: int64

# %%
df.to_csv(r'C:\Users\sivar\Downloads\traffic_stops_final3.csv', index=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

file_path = r'C:\Users\sivar\Downloads\traffic_stops_final9.csv'
df = pd.read_csv(file_path)

# %%
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age  \
# 0      2020-01-01  00:00:00       Canada             M          19
# 1      2020-01-01  00:01:00        India             M          58
# 2      2020-01-01  00:02:00          USA             M          76
# 3      2020-01-01  00:03:00       Canada             M          76
# 4      2020-01-01  00:04:00       Canada             M          75
# ...           ...       ...          ...           ...         ...
# 65533  2020-02-15  12:13:00        India             F          48
# 65534  2020-02-15  12:14:00       Canada             F          35
# 65535  2020-02-15  12:15:00          USA             M          41
# 65536  2020-02-15  12:16:00       Canada             F          63
# 65537  2020-02-15  12:17:00          USA             F          32
#
#       driver_race violation  search_conducted     search_type stop_outcome  \
# 0           Asian  Speeding              True  Vehicle Search       Ticket
# 1           Other     Other             False  Vehicle Search       Arrest
# 2           Black  Speeding             False           Frisk       Ticket
# 3           Black       DUI              True           Frisk      Warning
# 4           Other     Other             False  Vehicle Search       Arrest
# ...           ...       ...               ...             ...          ...
# 65533       Black     Other             False  Vehicle Search       Arrest
# 65534    Hispanic     Other              True  Vehicle Search       Ticket
# 65535       Asian       DUI              True           Frisk       Ticket
# 65536       Black     Other             False       No Search      Warning
# 65537       Other  Speeding              True       No Search       Ticket
#
#        is_arrested stop_duration  drugs_related_stop vehicle_number
# 0             True     16-30 Min                True     UP76DY3473
# 1             True     16-30 Min                True     RJ83PZ4441
# 2             True     16-30 Min                True     RJ32OM7264
# 3            False      0-15 Min                True     RJ76TI3807
# 4             True     16-30 Min               False     WB63BB8305
# ...            ...           ...                 ...            ...
# 65533         True     16-30 Min               False     DL56GW6568
# 65534        False     16-30 Min                True     TN73EO7098
# 65535         True       30+ Min                True     GJ33MX8328
# 65536         True      0-15 Min                True     KA24UZ8488
# 65537         True     16-30 Min               False     UP89PT2924
#
# [65538 rows x 14 columns]

# %%
df['stop_outcome'].value_counts()
# Out:
# stop_outcome
# Warning    21966
# Ticket     21838
# Arrest     21734
# Name: count, dtype: int64

# %%
df = df.drop(columns=['search_conducted', 'is_arrested'])

# %%
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age  \
# 0      2020-01-01  00:00:00       Canada             M          19
# 1      2020-01-01  00:01:00        India             M          58
# 2      2020-01-01  00:02:00          USA             M          76
# 3      2020-01-01  00:03:00       Canada             M          76
# 4      2020-01-01  00:04:00       Canada             M          75
# ...           ...       ...          ...           ...         ...
# 65533  2020-02-15  12:13:00        India             F          48
# 65534  2020-02-15  12:14:00       Canada             F          35
# 65535  2020-02-15  12:15:00          USA             M          41
# 65536  2020-02-15  12:16:00       Canada             F          63
# 65537  2020-02-15  12:17:00          USA             F          32
#
#       driver_race violation     search_type stop_outcome stop_duration  \
# 0           Asian  Speeding  Vehicle Search       Ticket     16-30 Min
# 1           Other     Other  Vehicle Search       Arrest     16-30 Min
# 2           Black  Speeding           Frisk       Ticket     16-30 Min
# 3           Black       DUI           Frisk      Warning      0-15 Min
# 4           Other     Other  Vehicle Search       Arrest     16-30 Min
# ...           ...       ...             ...          ...           ...
# 65533       Black     Other  Vehicle Search       Arrest     16-30 Min
# 65534    Hispanic     Other  Vehicle Search       Ticket     16-30 Min
# 65535       Asian       DUI           Frisk       Ticket       30+ Min
# 65536       Black     Other       No Search      Warning      0-15 Min
# 65537       Other  Speeding       No Search       Ticket     16-30 Min
#
#        drugs_related_stop vehicle_number
# 0                    True     UP76DY3473
# 1                    True     RJ83PZ4441
# 2                    True     RJ32OM7264
# 3                    True     RJ76TI3807
# 4                   False     WB63BB8305
# ...                   ...            ...
# 65533               False     DL56GW6568
# 65534                True     TN73EO7098
# 65535                True     GJ33MX8328
# 65536                True     KA24UZ8488
# 65537               False     UP89PT2924
#
# [65538 rows x 12 columns]

# %%
df.to_csv(r'C:\Users\sivar\Downloads\traffic_stops_final10.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65538 entries, 0 to 65537
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65538 non-null  object
#  1   stop_time           65538 non-null  object
#  2   country_name        65538 non-null  object
#  3   driver_gender       65538 non-null  object
#  4   driver_age          65538 non-null  int64
#  5   driver_race         65538 non-null  object
#  6   violation           65538 non-null  object
#  7   search_type         65538 non-null  object
#  8   stop_outcome        65538 non-null  object
#  9   stop_duration       65538 non-null  object
#  10  drugs_related_stop  65538 non-null  bool
#  11  vehicle_number      65538 non-null  object
# dtypes: bool(1), int64(1), object(10)
# memory usage: 5.6+ MB

# %%
print(type(df['stop_time'].iloc[0]))
# Out:
# <class 'datetime.time'>

# %%
df['stop_date'] = pd.to_datetime(df['stop_date']).dt.date

# %%
df['stop_time'] = pd.to_datetime(df['stop_time']).dt.time
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df['stop_time'] = pd.to_datetime(df['stop_time']).dt.time
#
# File f:\Python\Lib\site-packages\pandas\core\tools\datetimes.py:1072, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1070         result = arg.map(cache_array)
#    1071     else:
# -> 1072         values = convert_listlike(arg._values, format)
#    1073         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1074 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File f:\Python\Lib\site-packages\pandas\core\tools\datetimes.py:437, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     434 if format is not None and format != "mixed":
#     435     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
# --> 437 result, tz_parsed = objects_to_datetime64(
#     438     arg,
#     439     dayfirst=dayfirst,
#     440     yearfirst=yearfirst,
#     441     utc=utc,
#     442     errors=errors,
#     443     allow_object=True,
#     444 )
#     446 if tz_parsed is not None:
#     447     # We can take a shortcut since the datetime64 numpy array
#     448     # is in UTC
#     449     out_unit = np.datetime_data(result.dtype)[0]
#
# File f:\Python\Lib\site-packages\pandas\core\arrays\datetimes.py:2415, in objects_to_datetime64(data, dayfirst, yearfirst, utc, errors, allow_object, out_unit)
#    2412 # if str-dtype, convert
#    2413 data = np.asarray(data, dtype=np.object_)
# -> 2415 result, tz_parsed = tslib.array_to_datetime(
#    2416     data,
#    2417     errors=errors,
#    2418     utc=utc,
#    2419     dayfirst=dayfirst,
#    2420     yearfirst=yearfirst,
#    2421     creso=abbrev_to_npy_unit(out_unit),
#    2422 )
#    2424 if tz_parsed is not None:
#    2425     # We can take a shortcut since the datetime64 numpy array
#    2426     #  is in UTC
#    2427     return result, tz_parsed
#
# File pandas/_libs/tslib.pyx:412, in pandas._libs.tslib.array_to_datetime()
#
# File pandas/_libs/tslib.pyx:596, in pandas._libs.tslib.array_to_datetime()
#
# File pandas/_libs/tslib.pyx:588, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: <class 'datetime.time'> is not convertible to datetime, at position 0

# %%
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age  \
# 0      2020-01-01  00:00:00       Canada             M          19
# 1      2020-01-01  00:01:00        India             M          58
# 2      2020-01-01  00:02:00          USA             M          76
# 3      2020-01-01  00:03:00       Canada             M          76
# 4      2020-01-01  00:04:00       Canada             M          75
# ...           ...       ...          ...           ...         ...
# 65533  2020-02-15  12:13:00        India             F          48
# 65534  2020-02-15  12:14:00       Canada             F          35
# 65535  2020-02-15  12:15:00          USA             M          41
# 65536  2020-02-15  12:16:00       Canada             F          63
# 65537  2020-02-15  12:17:00          USA             F          32
#
#       driver_race violation     search_type stop_outcome stop_duration  \
# 0           Asian  Speeding  Vehicle Search       Ticket     16-30 Min
# 1           Other     Other  Vehicle Search       Arrest     16-30 Min
# 2           Black  Speeding           Frisk       Ticket     16-30 Min
# 3           Black       DUI           Frisk      Warning      0-15 Min
# 4           Other     Other  Vehicle Search       Arrest     16-30 Min
# ...           ...       ...             ...          ...           ...
# 65533       Black     Other  Vehicle Search       Arrest     16-30 Min
# 65534    Hispanic     Other  Vehicle Search       Ticket     16-30 Min
# 65535       Asian       DUI           Frisk       Ticket       30+ Min
# 65536       Black     Other       No Search      Warning      0-15 Min
# 65537       Other  Speeding       No Search       Ticket     16-30 Min
#
#        drugs_related_stop vehicle_number
# 0                    True     UP76DY3473
# 1                    True     RJ83PZ4441
# 2                    True     RJ32OM7264
# 3                    True     RJ76TI3807
# 4                   False     WB63BB8305
# ...                   ...            ...
# 65533               False     DL56GW6568
# 65534                True     TN73EO7098
# 65535                True     GJ33MX8328
# 65536                True     KA24UZ8488
# 65537               False     UP89PT2924
#
# [65538 rows x 12 columns]

# %%
import mysql.connector
mydb = mysql.connector.connect(
 host="localhost",
 user="root",
 password="",
)
print(mydb)
mycursor = mydb.cursor(buffered=True)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x000001DE54684980>

# %%
import pandas as pd


# 1️⃣ Load CSV
df = pd.read_csv( r'C:\Users\sivar\Downloads\traffic_stops_final10.csv')





# 4️⃣ Create database if not exists
mycursor.execute("CREATE DATABASE IF NOT EXISTS police")
mycursor.execute("USE police")

# 5️⃣ Create table if not exists
create_table_query = """
CREATE TABLE IF NOT EXISTS traffic_stops (
    stop_date DATE,
    stop_time TIME,
    country_name VARCHAR(50),
    driver_gender CHAR(1),
    driver_age INT,
    driver_race VARCHAR(50),
    violation VARCHAR(100),
    search_type VARCHAR(100),
    stop_outcome VARCHAR(100),
    stop_duration VARCHAR(20),
    drugs_related_stop BOOLEAN,
    vehicle_number VARCHAR(20)
);
"""
mycursor.execute(create_table_query)

# 6️⃣ Insert rows
insert_query = """
INSERT INTO traffic_stops (
    stop_date,
    stop_time,
    country_name,
    driver_gender,
    driver_age,
    driver_race,
    violation,
    search_type,
    stop_outcome,
    stop_duration,
    drugs_related_stop,
    vehicle_number
) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

for index, row in df.iterrows():
    mycursor.execute(insert_query, (
        row['stop_date'],
        row['stop_time'],
        row['country_name'],
        row['driver_gender'],
        row['driver_age'],
        row['driver_race'],
        row['violation'],
        row['search_type'],
        row['stop_outcome'],
        row['stop_duration'],
        row['drugs_related_stop'],
        row['vehicle_number']
    ))

mydb.commit()
mycursor.close()
mydb.close()

print("✅ Data inserted into 'police.traffic_stops' successfully.")
# Out:
# ✅ Data inserted into 'police.traffic_stops' successfully.

# %%
import pandas as pd
df = pd.read_csv( r'C:\Users\sivar\Downloads\traffic_stops_final10.csv')

# %%
print(df.isnull().sum())
# Out:
# stop_date             0
# stop_time             0
# country_name          0
# driver_gender         0
# driver_age            0
# driver_race           0
# violation             0
# search_type           0
# stop_outcome          0
# stop_duration         0
# drugs_related_stop    0
# vehicle_number        0
# dtype: int64
